# %% [markdown]
# # **🗒️ Explanation for YOLO Model with Dataset**
# You're utilizing the YOLO (You Only Look Once) model for object detection, and here's an explanation of your code and data:
#
# Model Selection: You've chosen the YOLO model for object detection.
#
# **Dataset Information:**
#
# **Classes**: Your dataset contains 20 classes of objects, including aeroplane, bicycle, bird, boat, bottle, bus, car, cat, chair, cow, dining table, dog, horse, motorbike, person, potted plant, sheep, sofa, train, and TV monitor.
# Number of Classes (nc): There are 20 classes in total.
# Roboflow Dataset: Your dataset is hosted on Roboflow, version 4, with the project named "project-pwhom." It's licensed under CC BY 4.0.
# URL: universe.roboflow.com/aadharsh-hariharan-gmail-com/project-pwhom/dataset/4
#
# **Workspace:** aadharsh-hariharan-gmail-com
#
# **License:** CC BY 4.0
#
# **Data Paths:**
#
# **Test Images: Located at /content/project-4/test/images.**
# **Training Images: Located at /content/project-4/train/images.**
# **Validation Images: Located at /content/project-4/valid/images.**

# %% [markdown]
# # **Import package and download the dataset**

# %%
# Importing the Roboflow and Ultralytics packages
# !pip install -q roboflow
# !pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 17.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# ...

# %%
# Import os and display the pictures

import os
from IPython.display import display, Image, clear_output

# Clear the output
clear_output()

# Execute the YOLO command
os.system("yolo mode=checks")
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 509, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.10/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are ('train', 'val', 'predict', 'export', 'track', 'benchmark').
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose', 'obb')
#                 MODE (required) is one of ('train', 'val', 'predict', 'export', 'track', 'benchmark')
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
# ...

# %%
# Download the dataset

from roboflow import Roboflow
rf = Roboflow(api_key="cIZnCteevof2Ochdg1xS")
project = rf.workspace("aadharsh-hariharan-gmail-com").project("project-pwhom")
dataset = project.version(4).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.11, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to project-4 in yolov8:: 100%|██████████| 9916/9916 [00:03<00:00, 2612.97it/s]

# %% [markdown]
# # **Train the model Yolo**

# %%
# Train model in 20 epochs and the image size is 640 pixels
# !yolo task=detect mode=train model=yolov8m.pt data=/content/project-4/data.yaml epochs=20 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 292MB/s]
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# **Validation**

# %%
# View validation in Model
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/project-4/data.yaml epochs=10 imgsz=640
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25851340 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/project-4/valid/labels.cache... 990 images, 15 backgrounds, 0 corrupt: 100% 990/990 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 62/62 [00:23<00:00,  2.63it/s]
#                    all        990       2952      0.789      0.688      0.763      0.545
#              aeroplane        990         63      0.946      0.825      0.937      0.677
#                bicycle        990         84      0.836       0.73      0.818      0.633
#                   bird        990        146      0.776      0.589      0.719       0.44
#                   boat        990         48      0.536      0.505      0.569      0.333
#                 bottle        990        114      0.847      0.631      0.689      0.482
# ...

# %% [markdown]
# **Predict**

# %%
# Predict Model
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.5 source=/content/project-4/data.yaml epochs=10 imgsz=640
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25851340 parameters, 0 gradients, 78.7 GFLOPs
#
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 568, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 406, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/predictor.py", line 213, in predict_cli
#     for _ in gen:  # noqa, running CLI inference without accumulating any outputs (do not modify)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 35, in generator_context
# ...

# %% [markdown]
# # Image

# %%
# Confidence Curve
Image(f'/content/runs/detect/train/F1_curve.png',width=640)

# %%
# Precision Recall Curve
Image(f'/content/runs/detect/train/PR_curve.png',width=640)

# %%
# Confusion Matrix
Image(f'/content/runs/detect/train/confusion_matrix.png',width=640)

# %%
# Results
Image(f'/content/runs/detect/train/results.png',width=640)

# %% [markdown]
# # **Predict and run model**

# %%
from ultralytics import YOLO
model=YOLO('/content/runs/detect/train/weights/best.pt')
results=model(source='/content/man-walking-his-dog-while-riding-his-bike-S3X5C4.jpg',show=True,conf=0.6,save=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/man-walking-his-dog-while-riding-his-bike-S3X5C4.jpg: 544x640 1 bicycle, 1 bus, 2 cars, 1 dog, 1 person, 179.7ms
# Speed: 11.5ms preprocess, 179.7ms inference, 918.3ms postprocess per image at shape (1, 3, 544, 640)
# Results saved to runs/detect/predict

# %%
# image detection and run model
Image(f'/content/runs/detect/predict/man-walking-his-dog-while-riding-his-bike-S3X5C4.jpg',width=640)

# %% [markdown]
# **Model Selection:**
#
# The YOLO model for object detection.
#
# **Dataset Information:**
#
# Dataset contains 20 classes of objects including aeroplane, bicycle, bird, boat, bottle, bus, car, cat, chair, cow, dining table, dog, horse, motorbike, person, potted plant, sheep, sofa, train, and TV monitor.
# There are 20 classes in total.
#
# **Roboflow Dataset:**
#
# Dataset is hosted on Roboflow, version 4, with the project named 'project-pwhom'.
# It's licensed under CC BY 4.0.
#
# **Data Paths:**
#
# **Test Images:** Located at /content/project-4/test/images.
#
# **Training Images:** Located at /content/project-4/train/images.
#
# **Import Package and Download the Dataset:**
#
# You have installed the Roboflow and Ultralytics packages.
# There was an error with the package dependency resolver due to missing packages like fastapi, kaleido, python-multipart, and uvicorn.
#
# **Execute the YOLO Command:**
#
# You attempted to execute the YOLO command 'yolo mode=checks', but it resulted in a ValueError.
#
# **Download the Dataset from Roboflow:**
#
# You have attempted to download the dataset from Roboflow but encountered an issue with the required ultralytics version.
#
# **Train the Model YOLO:**
#
# You tried to train the model using YOLO for 20 epochs and with an image size of 640 pixels.
#
# **Model Training Settings:**
#
# Training for 20 epochs with a batch size of 16 and image size of 640
# Using various settings for optimization, augmentation, and logging
# Model Optimization:
#
# AMP (Automatic Mixed Precision) is used for YOLOv8n model training
# Model is using AdamW optimizer with automatic determination of learning rate and momentum
#
# **Data and Label Preparation:**
#
# Preparing training and validation data
# Creating image caches and applying augmentations to the data
#
# **Model Performance:**
#
# Transferred parameters from pretrained weights
# Training is visualized and logged using TensorBoard
#
# **Further Configuration:**
#
# Freezing certain layers in the model
# Downloading pretrained weights for YOLOv8n model
#
# **Data Loading and Optimization:**
#
# Scanning and loading train and validation data with validation split
# Automatic determination of optimizer settings
#
# **Validation Results:**
#
# Validation was performed with 990 images and 15 backgrounds, with no corruption detected.
# Class images instances and various metrics were recorded for the validation set.
#
# **Inference Speed:**
#
# The model demonstrated a preprocessing speed of 0.3ms, inference speed of 7.5ms, and post-processing speed of 1.6ms per image.
# Results were saved to runs/detect/train.
#
# **Validation Code Utilized:**
#
# Use of validation code for YOLO task on the model with specific parameters.
# View validation was performed on the Model.
